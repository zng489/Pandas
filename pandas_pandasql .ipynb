# %%
#!pip install pandasql

# %%
import pandas as pd
from pandasql import sqldf

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
excluidas = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/vagas/vagas_excluidas.csv', index_col=0)
excluidas.head(3)
# Out:
#                                                  url    codigo  \
# 0  https://www.vagas.com.br/vagas/v2189607/vended...  v2189607
# 1  https://www.vagas.com.br/vagas/v2183497/analis...  v2183497
# 2  https://www.vagas.com.br/vagas/v2196056/analis...  v2196056
#
#    situacao_da_vaga dif_data data_do_request
# 0               404  65 days        7/7/2021
# 1               404  65 days        7/7/2021
# 2               404  65 days        7/7/2021

# %%
n_excluidas = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/vagas/vagas_nao_excluidas.csv', index_col=0)
n_excluidas.head(3)
# Out:
#                                                  url    codigo  \
# 0  https://www.vagas.com.br/vagas/v2185836/engenh...  v2185836
# 1  https://www.vagas.com.br/vagas/v2190381/estagi...  v2190381
# 2  https://www.vagas.com.br/vagas/v2192440/repres...  v2192440
#
#    situacao_da_vaga dif_data data_do_request
# 0               200  65 days        7/7/2021
# 1               200  65 days        7/7/2021
# 2               200  65 days        7/7/2021

# %%
df_404 = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/vagas/site_request_404.csv', index_col=0)
df_404.head(3)
# Out:
#         id       site  adicional  beneficios    codigo  \
# 212254   0  sitevagas        NaN         NaN  v2196495
# 212255   1  sitevagas        NaN         NaN  v2200823
# 212256   4  sitevagas        NaN         NaN  v2187790
#
#                                                  conteudo          empresa  \
# 212254   RequisitosFormacao Ciencias Contabeis;Conheci...          Marimex
# 212255   Jovem Aprendiz  - Sua futura posicao?Na posic...        Givaudan
# 212256   O projeto Multicor, foi feito para o recrutam...  Grupo Cataratas
#
#         horario      localidade  \
# 212254      NaN       Sao Paulo
# 212255      NaN       Sao Paulo
# 212256      NaN  Rio de Janeiro
#
#                                                 profissao regime  \
# 212254                  Vaga Analista Contabil Pl
# 212255                    Vagas   Jovem Aprendiz
# 212256            Banco de Vagas   Projeto Multicor   ...
#
# ...

# %%
df_200 = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/vagas/site_request_list.csv', index_col=0)
df_200.head(3)
# Out:
#      id       site  adicional  beneficios    codigo  \
# 52  743  sitevagas        NaN         NaN  v2189607
# 53  750  sitevagas        NaN         NaN  v2183497
# 54  786  sitevagas        NaN         NaN  v2185836
#
#                                              conteudo        empresa  horario  \
# 52  Atuara com atendimento ativo de vendas, prospe...   Confidencial      NaN
# 53  RequisitosFormacao em Farmacia.Experiencia com...  Uniao Quimica      NaN
# 54  Estamos buscando Engenheiro Mecanico com exper...   Confidencial      NaN
#
#    localidade                                          profissao regime  \
# 52  Sao Paulo                             Vendedor - Poa
# 53  Sao Paulo            Analista de Garantia da Qualidade Se...
# 54   Sao Luis            Engenheiro Mecanico Pleno (Projetos)...
#
#          salario                                                url  \
# 52   a combinar   https://www.vagas.com.br/vagas/v2189607/vended...
# ...

# %%
df_sum = sqldf("SELECT * FROM n_excluidas UNION  SELECT * FROM excluidas;", locals())
df_sum.head(3)
# Out:
#                                                  url    codigo  \
# 0  https://www.vagas.com.br/vagas/v2162156/superv...  v2162156
# 1  https://www.vagas.com.br/vagas/v2168485/pessoa...  v2168485
# 2  https://www.vagas.com.br/vagas/v2174124/analis...  v2174124
#
#    situacao_da_vaga dif_data data_do_request
# 0               404  65 days        7/7/2021
# 1               200  65 days        7/7/2021
# 2               404  65 days        7/7/2021

# %%
df_nova_request = sqldf("SELECT df_200.id, df_200.site, df_200.adicional, df_200.beneficios, df_200.codigo, df_200.conteudo, df_200.empresa, df_200.horario, df_200.localidade, df_200.profissao, df_200.regime, df_200.salario, df_200.url, df_200.data_publicada, df_200.vagas, df_200.data_do_scraping,df_sum.situacao_da_vaga,df_sum.dif_data FROM df_200 INNER JOIN df_sum ON df_200.codigo=df_sum.codigo;", locals())
df_nova_request.head(3)
# Out:
#     id       site adicional beneficios    codigo  \
# 0  743  sitevagas      None       None  v2189607
# 1  750  sitevagas      None       None  v2183497
# 2  786  sitevagas      None       None  v2185836
#
#                                             conteudo        empresa horario  \
# 0  Atuara com atendimento ativo de vendas, prospe...   Confidencial    None
# 1  RequisitosFormacao em Farmacia.Experiencia com...  Uniao Quimica    None
# 2  Estamos buscando Engenheiro Mecanico com exper...   Confidencial    None
#
#   localidade                                          profissao regime  \
# 0  Sao Paulo                             Vendedor - Poa
# 1  Sao Paulo            Analista de Garantia da Qualidade Se...
# 2   Sao Luis            Engenheiro Mecanico Pleno (Projetos)...
#
#         salario                                                url  \
# 0   a combinar   https://www.vagas.com.br/vagas/v2189607/vended...
# ...

# %%
site_vagas = sqldf("SELECT * FROM df_404 UNION  SELECT * FROM df_nova_request;", locals())
site_vagas.head(4)
# Out:
#    id       site adicional beneficios    codigo  \
# 0   0  sitevagas      None       None  v2196495
# 1   1  sitevagas      None       None  v2200823
# 2   2  sitevagas      None       None  v2201779
# 3   3  sitevagas      None       None  v2188712
#
#                                             conteudo                 empresa  \
# 0   RequisitosFormacao Ciencias Contabeis;Conheci...                 Marimex
# 1   Jovem Aprendiz  - Sua futura posicao?Na posic...               Givaudan
# 2  Entao confira essa oportunidade para area de A...                Ultragaz
# 3   Escopo da posicaoAssessorar o processo de lev...  Trouw Nutrition Brasil
#
#   horario localidade                                          profissao  \
# 0    None  Sao Paulo                  Vaga Analista Contabil Pl
# 1    None  Sao Paulo                    Vagas   Jovem Aprendiz
# 2    None   Curitiba                  Auxiliar/                     ...
# ...

# %%
site_vagas.to_csv('site_vagas_request_12_7_2021.csv')

# %%
#########
#########
#########
#########
#########
#########

# %%
#def infojobs():
excluidas = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/infojobs/infojobs_excluidas.csv', index_col=0)
n_excluidas = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/infojobs/infojobs_nao_excluidas.csv', index_col=0)
df_404 = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/infojobs/infojobs_request_404.csv', index_col=0)
df_200 = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/infojobs/infojobs_request_200.csv', index_col=0)
df_sum = sqldf("SELECT * FROM n_excluidas UNION  SELECT * FROM excluidas;", locals())
df_nova_request = sqldf("SELECT df_200.id, df_200.site, df_200.adicional, df_200.beneficios, df_200.codigo, df_200.conteudo, df_200.empresa, df_200.horario, df_200.localidade, df_200.profissao, df_200.regime, df_200.salario, df_200.url, df_200.data_publicada, df_200.vagas, df_200.data_do_scraping,df_sum.situacao_da_vaga,df_sum.dif_data FROM df_200 INNER JOIN df_sum ON df_200.codigo=df_sum.codigo;", locals())

# %%
df_404.drop(['data'], axis=1, inplace=True)
df_404
# Out:
#           id      site adicional beneficios   codigo  \
# 0          1  infojobs      None       None  7207593
# 1          2  infojobs      None       None  7207597
# 2          3  infojobs      None       None  7206929
# 3          4  infojobs      None       None  7207595
# 4          5  infojobs      None       None  7206056
# ...      ...       ...       ...        ...      ...
# 46406  65033  infojobs      None       None  7156999
# 46407  65034  infojobs      None       None  7156995
# 46408  65035  infojobs      None       None  7156994
# 46409  65036  infojobs      None       None  7155931
# 46410  65038  infojobs      None       None  7155926
#
#                                                 conteudo  \
# 0      Area e especializacao profissional: Comercial,...
# 1      Area e especializacao profissional: Informatic...
# 2      Area e especializacao profissional: Comercial,...
# 3      Area e especializacao profissional: Informatic...
# ...

# %%
# sqldf("ALTER TABLE df_404 DROP COLUMN data;", locals())

# %%
df_nova_request
# Out:
#           id      site adicional beneficios   codigo  \
# 0         42  infojobs      None       None  7207632
# 1         67  infojobs      None       None  7066063
# 2         70  infojobs      None       None  7207288
# 3         71  infojobs      None       None  7207266
# 4         72  infojobs      None       None  7078693
# ...      ...       ...       ...        ...      ...
# 18625  65021  infojobs      None       None  7222625
# 18626  65023  infojobs      None       None  7229146
# 18627  65025  infojobs      None       None  7221463
# 18628  65026  infojobs      None       None  7081901
# 18629  65039  infojobs      None       None  7155922
#
#                                                 conteudo  \
# 0      Area e especializacao profissional: Administra...
# 1      Area e especializacao profissional: Servicos G...
# 2      Area e especializacao profissional: Administra...
# 3      Area e especializacao profissional: Comercial,...
# ...

# %%
infojobs = sqldf("SELECT * FROM df_404 UNION SELECT * FROM df_nova_request;", locals())
infojobs
# Out:
#           id      site adicional beneficios   codigo  \
# 0          0  infojobs      None       None  7129630
# 1          1  infojobs      None       None  7207593
# 2          2  infojobs      None       None  7207597
# 3          3  infojobs      None       None  7206929
# 4          4  infojobs      None       None  7207595
# ...      ...       ...       ...        ...      ...
# 65036  65036  infojobs      None       None  7155931
# 65037  65037  infojobs      None       None  7155929
# 65038  65038  infojobs      None       None  7155926
# 65039  65039  infojobs      None       None  7155922
# 65040  65040  infojobs      None       None  7227410
#
#                                                 conteudo  \
# 0      Area e especializacao profissional: Telemarket...
# 1      Area e especializacao profissional: Comercial,...
# 2      Area e especializacao profissional: Informatic...
# 3      Area e especializacao profissional: Comercial,...
# ...

# %%
infojobs.to_csv('infojobs_request_12_7_2021.csv')

# %%
#########
#########
#########
#########
#########
#########

# %%
df = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/base_t0_06_07_2021.csv', index_col=0)
df
# Out:
# C:\Users\Zng-LENOVO\Anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        id       site  adicional  beneficios  \
# 1       1     indeed        NaN         NaN
# 2       2     indeed        NaN         NaN
# 3       3     indeed        NaN         NaN
# 4       4     indeed        NaN         NaN
# 5       5     indeed        NaN         NaN
# ..    ...        ...        ...         ...
# 201  2306  sitevagas        NaN         NaN
# 202  2307  sitevagas        NaN         NaN
# 203  2341  sitevagas        NaN         NaN
# 204  2342  sitevagas        NaN         NaN
# 205  2348  sitevagas        NaN         NaN
#
#                                                 codigo  \
# 1    /rc/clk?jk=d6340519cca5653c&fccid=92d9703d1d0a...
# 2    /rc/clk?jk=7d84d7eb06028bdb&fccid=dd616958bd9d...
# ...

# %%
df = df[df['site'] == 'indeed']
df
# Out:
#       id    site  adicional  beneficios  \
# 1      1  indeed        NaN         NaN
# 2      2  indeed        NaN         NaN
# 3      3  indeed        NaN         NaN
# 4      4  indeed        NaN         NaN
# 5      5  indeed        NaN         NaN
# ..   ...     ...        ...         ...
# 0      0  indeed        NaN         NaN
# 1     13  indeed        NaN         NaN
# 2    119  indeed        NaN         NaN
# 3   1285  indeed        NaN         NaN
# 4   1318  indeed        NaN         NaN
#
#                                                codigo  \
# 1   /rc/clk?jk=d6340519cca5653c&fccid=92d9703d1d0a...
# 2   /rc/clk?jk=7d84d7eb06028bdb&fccid=dd616958bd9d...
# 3   /rc/clk?jk=bceb265f26d09c59&fccid=e8e463c81f07...
# 4   /rc/clk?jk=8347acbcf2d0c13d&fccid=8e10d571a543...
# 5   /rc/clk?jk=d2ed709f9a058b83&fccid=3cc75642f264...
# ..                                                ...
# 0                        /cmp/Maxim-E-Hailing-Service
# ...

# %%
d = pd.concat([site_vagas, infojobs, df])

# %%
d
# Out:
#       id       site adicional beneficios                              codigo  \
# 0      0  sitevagas      None       None                            v2196495
# 1      1  sitevagas      None       None                            v2200823
# 2      2  sitevagas      None       None                            v2201779
# 3      3  sitevagas      None       None                            v2188712
# 4      4  sitevagas      None       None                            v2187790
# ..   ...        ...       ...        ...                                 ...
# 0      0     indeed       NaN        NaN        /cmp/Maxim-E-Hailing-Service
# 1     13     indeed       NaN        NaN         /cmp/Aec-Centro-De-Contatos
# 2    119     indeed       NaN        NaN  /cmp/The-Coca--cola-Company-(tccc)
# 3   1285     indeed       NaN        NaN  /cmp/Vivo-(telef%C3%B4nica-Brasil)
# 4   1318     indeed       NaN        NaN         /cmp/Igu%C3%A1-Saneamento-2
#
# ...

# %%
q = pd.read_csv('C:/Users/Zng-LENOVO/Desktop/request/VagasConsolidado.csv', index_col=0, error_bad_lines=False)
#q.to_csv('VagasConsolidado.csv')
q
# Out:
#               site                                          adicional  \
# id
# 0      vagascertas  Requisitos:Necessário possuir conhecimento e e...
# 1      vagascertas  Requisitos:Desejável ser prestativo, atencioso...
# 2      vagascertas  Requisitos:Ensino Médio completo;Excel Avançad...
# 3      vagascertas  Requisitos: Experiência em vendas de rede lógi...
# 4      vagascertas  Requisitos:Necessário experiência na função (o...
# ...            ...                                                ...
# 97872        catho                                                  -
# 97873        catho  Ter fácil acesso a Contagem-MG será um diferen...
# 97874        catho  Ter fácil acesso próximo da região de Venda No...
# 97875        catho                                                  -
# 97876        catho                                                  -
#
#                                               beneficios    codigo  \
# id
# ...

# %%
g = pd.concat([d, q])

# %%
g
# Out:
#         id       site                                          adicional  \
# 0      0.0  sitevagas                                               None
# 1      1.0  sitevagas                                               None
# 2      2.0  sitevagas                                               None
# 3      3.0  sitevagas                                               None
# 4      4.0  sitevagas                                               None
# ...    ...        ...                                                ...
# 97872  NaN      catho                                                  -
# 97873  NaN      catho  Ter fácil acesso a Contagem-MG será um diferen...
# 97874  NaN      catho  Ter fácil acesso próximo da região de Venda No...
# 97875  NaN      catho                                                  -
# 97876  NaN      catho                                                  -
#
#                                               beneficios    codigo  \
# ...

# %%
g.fillna("vazio", inplace=True)
g
# Out:
#           id       site                                          adicional  \
# 0          0  sitevagas                                              vazio
# 1          1  sitevagas                                              vazio
# 2          2  sitevagas                                              vazio
# 3          3  sitevagas                                              vazio
# 4          4  sitevagas                                              vazio
# ...      ...        ...                                                ...
# 97872  vazio      catho                                                  -
# 97873  vazio      catho  Ter fácil acesso a Contagem-MG será um diferen...
# 97874  vazio      catho  Ter fácil acesso próximo da região de Venda No...
# 97875  vazio      catho                                                  -
# 97876  vazio      catho                                                  -
#
# ...

# %%
g.fillna("vazio", inplace=True)

# %%
g['dif_data'].replace('days','',regex=True, inplace=True)

# %%
g
# Out:
#           id       site                                          adicional  \
# 0          0  sitevagas                                              vazio
# 1          1  sitevagas                                              vazio
# 2          2  sitevagas                                              vazio
# 3          3  sitevagas                                              vazio
# 4          4  sitevagas                                              vazio
# ...      ...        ...                                                ...
# 97872  vazio      catho                                                  -
# 97873  vazio      catho  Ter fácil acesso a Contagem-MG será um diferen...
# 97874  vazio      catho  Ter fácil acesso próximo da região de Venda No...
# 97875  vazio      catho                                                  -
# 97876  vazio      catho                                                  -
#
# ...

# %%
g['vagas'].replace('vaga:','',regex=True, inplace=True)

# %%
g['data_publicada'].replace('vazio','',regex=True, inplace=True)

# %%
g
# Out:
#           id       site                                          adicional  \
# 0          0  sitevagas                                              vazio
# 1          1  sitevagas                                              vazio
# 2          2  sitevagas                                              vazio
# 3          3  sitevagas                                              vazio
# 4          4  sitevagas                                              vazio
# ...      ...        ...                                                ...
# 97872  vazio      catho                                              vazio
# 97873  vazio      catho  Ter fácil acesso a ContagemvazioMG será um dif...
# 97874  vazio      catho  Ter fácil acesso próximo da região de Venda No...
# 97875  vazio      catho                                              vazio
# 97876  vazio      catho                                              vazio
#
# ...

# %%
g.to_csv("yuan_luis_base.csv")
